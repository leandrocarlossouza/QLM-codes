# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from scipy.fftpack import dct
import math
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from pca_emnist import *
from time import perf_counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics
from KFolderCV import *
from joblib import Parallel, delayed

kf = KFolderCV(10)
X, y = fit_pca_on_full_dataset("bymerge")
#y = y-1
print(np.min(y))
print(np.max(y))

for neurons in range(1,3):
    for number in range(10,41,10): 
        print(f"Terms: {number} neurons: {neurons}")
        ma, sa, mt, st, nv = kf.cross_validate(X,y,neurons,number, 0)
        print(f"power-> variables: {nv} accuracy: {100*ma:.2f} ({100*sa:.2f}) time: {mt:.2f}")
        ma, sa,mt, st, nv = kf.cross_validate(X,y,neurons,number, 1)
        print(f"multivariate-> variables: {nv} accuracy:  {100*ma:.2f} ({100*sa:.2f}) time: {mt:.2f}")
# Out:
# Loading EMNIST split: bymerge
# BYMERGE - Training samples: 697932
# BYMERGE - Test samples: 116323
# BYMERGE - Number of classes: 47
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5125/99553791.py in <module>
#      16
#      17 kf = KFolderCV(10)
# ---> 18 X, y = fit_pca_on_full_dataset("bymerge")
#      19 #y = y-1
#      20 print(np.min(y))
#
# ~/Dropbox/quantum/1qndit-v3/pca_emnist.py in fit_pca_on_full_dataset(set_name)
#      61
#      62     # Collect images and labels from the training set
# ---> 63     for images, labels in train_loader:
#      64         all_images.append(images.view(images.size(0), -1))  # Flatten images to 1D
#      65         all_labels.append(labels)  # Collect corresponding labels
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.10/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     144
#     145         if self.transform is not None:
# --> 146             img = self.transform(img)
#     147
#     148         if self.target_transform is not None:
#
# ~/.local/lib/python3.10/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# ~/.local/lib/python3.10/site-packages/torchvision/transforms/transforms.py in forward(self, img)
#    1571             PIL Image or Tensor: Grayscaled image.
#    1572         """
# -> 1573         return F.rgb_to_grayscale(img, num_output_channels=self.num_output_channels)
#    1574
#    1575     def __repr__(self) -> str:
#
# ~/.local/lib/python3.10/site-packages/torchvision/transforms/functional.py in rgb_to_grayscale(img, num_output_channels)
#    1287         _log_api_usage_once(rgb_to_grayscale)
#    1288     if not isinstance(img, torch.Tensor):
# -> 1289         return F_pil.to_grayscale(img, num_output_channels)
#    1290
#    1291     return F_t.rgb_to_grayscale(img, num_output_channels)
#
# ~/.local/lib/python3.10/site-packages/torchvision/transforms/_functional_pil.py in to_grayscale(img, num_output_channels)
#     337
#     338     if num_output_channels == 1:
# --> 339         img = img.convert("L")
#     340     elif num_output_channels == 3:
#     341         img = img.convert("L")
#
# /usr/lib/python3/dist-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     899                 mode = "RGBA"
#     900         if not mode or (mode == self.mode and not matrix):
# --> 901             return self.copy()
#     902
#     903         if matrix:
#
# /usr/lib/python3/dist-packages/PIL/Image.py in copy(self)
#    1123         :returns: An :py:class:`~PIL.Image.Image` object.
#    1124         """
# -> 1125         self.load()
#    1126         return self._new(self.im.copy())
#    1127
#
# /usr/lib/python3/dist-packages/PIL/Image.py in load(self)
#     824
#     825         if self.im:
# --> 826             if cffi and USE_CFFI_ACCESS:
#     827                 if self.pyaccess:
#     828                     return self.pyaccess
#
# KeyboardInterrupt:
